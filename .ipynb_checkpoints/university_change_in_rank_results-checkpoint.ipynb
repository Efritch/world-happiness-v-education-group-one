# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
univ_rank_changes = pd.read_csv('Results/univ_rank_changes.csv')
univ_rank_changes.head()
# Out:
#    year_2019  year_2018                              institution_name  \
# 0          1          1   MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)
# 1          2          2                           STANFORD UNIVERSITY
# 2          3          3                            HARVARD UNIVERSITY
# 3          4          4  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)
# 4          5          6                          UNIVERSITY OF OXFORD
#
#    rank_change         country  overall_rank
# 0            0   United States            19
# 1            0   United States            19
# 2            0   United States            19
# 3            0   United States            19
# 4            1  United Kingdom            15

# %%
# Create a dataframe to include the 15 universities that had the most positive change in rank
# from 2018 to 2019
best_univ_change = univ_rank_changes.sort_values(by=['rank_change'], ascending=False)
best_15 = best_univ_change.nlargest(15,'rank_change')
best_15
# Out:
#      year_2019  year_2018                                   institution_name  \
# 361        363        501                        TECHNISCHE UNIVERSITÄT GRAZ
# 314        315        451                                 KHALIFA UNIVERSITY
# 690        701        801                       CHUNGNAM NATIONAL UNIVERSITY
# 603        601        701    LOBACHEVSKY STATE UNIVERSITY OF NIZHNI NOVGOROD
# 702        701        801  SAMARA NATIONAL RESEARCH UNIVERSITY (SAMARA UN...
# 712        701        801            UNIVERSITÀ DEGLI STUDI DI SIENA (UNISI)
# 716        701        801                                UNIVERSITÄT ROSTOCK
# 720        701        801                          UNIVERSITY OF EAST LONDON
# 547        551        651                            QUAID-I-AZAM UNIVERSITY
# 721        701        801                            UNIVERSITY OF GREENWICH
# 630        601        701                             UNIVERSITY OF PLYMOUTH
# 624        601        701                    UNIVERSITI UTARA MALAYSIA (UUM)
# 611        601        701                                      SMITH COLLEGE
# 606        601        701                        OSAKA PREFECTURE UNIVERSITY
# 508        511        601                                    ITMO UNIVERSITY
#
#      rank_change               country  overall_rank
# 361          138               Austria            10
# 314          136  United Arab Emirates            21
# 690          100           South Korea            54
# 603          100                Russia            68
# 702          100                Russia            68
# 712          100                 Italy            36
# 716          100               Germany            17
# 720          100        United Kingdom            15
# 547          100              Pakistan            67
# 721          100        United Kingdom            15
# 630          100        United Kingdom            15
# 624          100              Malaysia            80
# 611          100         United States            19
# 606          100                 Japan            58
# 508           90                Russia            68

# %%
# Create chart to show the top 15 universities that had the greatest positive change in rank
ax = best_15.plot.bar(x='institution_name', y='rank_change')
plt.title('Universities with Most Positive Change in Rank (2018 to 2019)')
plt.xlabel('University')
plt.ylabel('Change in Rank')

# Save full figure as PNG file
plt.savefig("Results/most_positive_change_in_rank.png")

# %%
# Create a dataframe to include the 15 universities that had the most negative change in rank
# from 2018 to 2019
worst_univ_change = univ_rank_changes.sort_values(by=['rank_change'], ascending=True)
worst_15 = worst_univ_change.nsmallest(15,'rank_change')
worst_15
# Out:
#      year_2019  year_2018                                institution_name  \
# 639        801        601                            UNIVERSITY OF ZAGREB
# 816        801        651                               KUWAIT UNIVERSITY
# 673        651        501                           UNIVERSITY OF BAGHDAD
# 850        801        651        UNIVERSIDAD CATÓLICA ANDRÉS BELLO - UCAB
# 545        551        401                    LEIBNIZ UNIVERSITÄT HANNOVER
# 621        601        461                             UNIVERSITÄT POTSDAM
# 570        571        441                      UNIVERSITÉ PARIS DESCARTES
# 530        531        411    TARAS SHEVCHENKO NATIONAL UNIVERSITY OF KYIV
# 546        551        431        PONTIFICIA UNIVERSIDAD CATÓLICA DEL PERÚ
# 359        363        259  NORWEGIAN UNIVERSITY OF SCIENCE AND TECHNOLOGY
# 644        651        551                           CHIANG MAI UNIVERSITY
# 904        801        701                         UNIVERSITY OF BUCHAREST
# 762        751        651                        UNIVERSIDADE DE BRASÍLIA
# 623        601        501                          UNIVERSITÉ DE FRIBOURG
# 761        751        651        UNIVERSIDADE CATÓLICA PORTUGUESA, LISBOA
#
#      rank_change      country  overall_rank
# 639         -200      Croatia            75
# 816         -150       Kuwait            51
# 673         -150         Iraq           126
# 850         -150    Venezuela           108
# 545         -150      Germany            17
# 621         -140      Germany            17
# 570         -130       France            24
# 530         -120      Ukraine           133
# 546         -120         Peru            65
# 359         -104       Norway             3
# 644         -100     Thailand            52
# 904         -100      Romania            48
# 762         -100       Brazil            32
# 623         -100  Switzerland             6
# 761         -100     Portugal            66

# %%
# Create chart to show the top 15 universities that had the greatest positive change in rank
ay = worst_15.plot.bar(x='institution_name', y='rank_change')
plt.title('Universities with Most Negative Change in Rank (2018 to 2019)')
plt.xlabel('University')
plt.ylabel('Change in Rank')

# Save full figure as PNG file
plt.savefig("Results/most_negative_change_in_rank.png")
